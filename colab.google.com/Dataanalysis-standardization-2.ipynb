# %% [markdown]
# # 0. Working more seamlessly
#
# <input type="date" name="created_date" value="2020-08-04">
#
# <annotation msg="This version of notebook is now released as <img src='https://img.icons8.com/ios/50/000000/alpha.png'" />

# %% [markdown]
# # 1. Just installing jupyterlab

# %%
# !pip install jupyter jupyterlab rattlepy
# Out:
# ...
#      |████████████████████████████████| 7.8MB 14.1MB/s
# ...
#      |████████████████████████████████| 61kB 9.6MB/s
# ...
#   Found existing installation: jsonschema 2.6.0
#     Uninstalling jsonschema-2.6.0:
#       Successfully uninstalled jsonschema-2.6.0
# ...

# %% [markdown]
# #2. Download ngrok

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2020-08-04 10:13:54--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 18.208.90.15, 52.201.131.65, 54.85.41.146, ...
# Connecting to bin.equinox.io (bin.equinox.io)|18.208.90.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  36.3MB/s    in 0.4s
#
# 2020-08-04 10:13:55 (36.3 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
get_ipython().system_raw('./ngrok http 8889 &')
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://26fea55326c8.ngrok.io

# %%
# !curl -s http://localhost:4041/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://71be74b316f2.ngrok.io

# %% [markdown]
# # 3. Stopping all dangling process

# %%
# !lsof -i:8889
# Out:
# COMMAND PID USER   FD   TYPE DEVICE SIZE/OFF NODE NAME
# python3 347 root   59u  IPv4  51986      0t0  TCP localhost:8889 (LISTEN)

# %%
# !kill -9 347

# %%
# !lsof -i:8889

# %% [markdown]
# # 4. Using bottle

# %%
try:
  from bottle import Bottle, run
except:
  # !pip install bottle
  from bottle import Bottle, run
app = Bottle()

@app.route('/')
def hello():
    return "<html><head><center>Welcome to <a href='https://hub.docker.com/r/yoshinobusekiyu4docker/motorlab-cloud'>motrorlab-cloud!</a></center></head></html>"

run(app, host='localhost', port=8889)
# Out:
# ...
#      |████████████████████████████████| 92kB 2.8MB/s eta 0:00:011
# ...
# Bottle v0.12.18 server starting up (using WSGIRefServer())...
# Listening on http://localhost:8889/
# Hit Ctrl-C to quit.
#
# 127.0.0.1 - - [04/Aug/2020 10:14:14] "GET / HTTP/1.1" 404 728
# 127.0.0.1 - - [04/Aug/2020 10:14:14] "GET /favicon.ico HTTP/1.1" 404 750
# 127.0.0.1 - - [04/Aug/2020 10:14:24] "GET /hello HTTP/1.1" 200 147

# %% [markdown]
# # 5. Launching jupyterlab

# %%
# !jupyter lab --ip=0.0.0.0 --port=8889 --allow-root
# Out:
# |DEBUG|Paths used for configuration of jupyter_notebook_config:
#     	/etc/jupyter/jupyter_notebook_config.json
# |DEBUG|Paths used for configuration of jupyter_notebook_config:
#     	/usr/local/etc/jupyter/jupyter_notebook_config.d/jupyterlab.json
#     	/usr/local/etc/jupyter/jupyter_notebook_config.json
# |DEBUG|Paths used for configuration of jupyter_notebook_config:
#     	/usr/etc/jupyter/jupyter_notebook_config.json
# |DEBUG|Paths used for configuration of jupyter_notebook_config:
#     	/root/.jupyter/jupyter_notebook_config.json
# |INFO|google.colab serverextension initialized.
# |INFO|JupyterLab extension loaded from /usr/local/lib/python3.6/dist-packages/jupyterlab
# |INFO|JupyterLab application directory is /usr/local/share/jupyter/lab
# |WARNING|JupyterLab server extension not enabled, manually loading...
# |INFO|JupyterLab extension loaded from /usr/local/lib/python3.6/dist-packages/jupyterlab
# |INFO|JupyterLab application directory is /usr/local/share/jupyter/lab
# ...

# %% [markdown]
# # Copyrights
#
# All rights reserved for 吉延石油株式会社 and the publishers of scraped resources.
#
# 参考：
#
# * https://qiita.com/a2kiti/items/a6ae6715033bf22f7afc
